# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('Pettigrew_FindingAid.xlsx', skiprows = 3)

# %%
df = df.dropna().reset_index()

# %%
df
# Out:
#      index  Box Number Folder Number  \
# 0        0         1.0             1
# 1        1         1.0             2
# 2        2         1.0             3
# 3        3         1.0             4
# 4        5         1.0             5
# 5        6         1.0             6
# 6        8         1.0             7
# 7       10         1.0             8
# 8       12         1.0             9
# 9       13         1.0            10
# 10      14         1.0            11
# 11      15         1.0            12
# 12      17         1.0            13
# 13      19         1.0            14
# 14      21         1.0            15
# 15      22         1.0            16
# 16      24         1.0            17
# 17      26         1.0            18
# 18      28         1.0            19
# 19      29         1.0            20
# 20      30         1.0            21
# 21      32         1.0            22
# 22      34         1.0            23
# 23      36         1.0            24
# ...

# %%
df['Box Number'].plot(kind = 'bar')

# %%
df['Box Number'].plot(kind = 'line')

# %%
df.plot(x = 'Box Number', y = 'Folder Number') #won't work because there's a non numerical value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-e5c54d69230e> in <module>
# ----> 1 df.plot(x = 'Box Number', y = 'Folder Number') #won't work because there's a non numerical value
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# ...

# %%
df.groupby(['Box Number'])['Box Number'].count().plot(kind = 'bar')

# %%
# how many boxes have 'n.d.'?

# %%
df[ df['Date'].str.contains('n.d.') ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-f0bfde301d82> in <module>
# ----> 1 df[ df['Date'].str.contains('n.d.') ]
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2081     def _getitem_array(self, key):
#    2082         # also raises Exception if object array with NA values
# -> 2083         if com.is_bool_indexer(key):
#    2084             # warning here just in case -- previously __setitem__ was
# ...

# %%
df
# Out:
#       Box Number Folder Number  \
# 0            1.0             1
# 1            1.0             2
# 2            1.0             3
# 3            1.0             4
# 5            1.0             5
# 6            1.0             6
# 8            1.0             7
# 10           1.0             8
# 12           1.0             9
# 13           1.0            10
# 14           1.0            11
# 15           1.0            12
# 17           1.0            13
# 19           1.0            14
# 21           1.0            15
# 22           1.0            16
# 24           1.0            17
# 26           1.0            18
# 28           1.0            19
# 29           1.0            20
# 30           1.0            21
# 32           1.0            22
# 34           1.0            23
# 36           1.0            24
# 37           1.0            25
# 38           1.0            26
# 39           1.0            27
# 41           1.0            28
# 43           1.0            29
# ...

# %%
set(df['Date'].str.contains('n.d.'))
# Out:
# {False, True, nan}

# %%
df['Date'].str.contains('n.d.')
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 5       False
# 6        True
# 8       False
# 10      False
# 12      False
# 13      False
# 14      False
# 15      False
# 17      False
# 19      False
# 21      False
# 22      False
# 24      False
# 26      False
# 28      False
# 29       True
# 30      False
# 32      False
# 34      False
# 36       True
# 37      False
# 38      False
# 39      False
# 41      False
# 43      False
# 45      False
#         ...
# 966     False
# 968     False
# 970     False
# 971     False
# 972     False
# 974     False
# 975     False
# 977     False
# 979     False
# 980     False
# 982     False
# 984     False
# 986     False
# 988     False
# 990     False
# 991     False
# 993     False
# 994     False
# 996     False
# 998     False
# 1000    False
# 1002     True
# 1003    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# 1010    False
# 1011    False
# 1012    False
# ...

# %%
df['Folder Number'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-83b05a2df592> in <module>
# ----> 1 df['Folder Number'].plot()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2444                            colormap=colormap, table=table, yerr=yerr,
#    2445                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2446                            **kwds)
#    2447     __call__.__doc__ = plot_series.__doc__
#    2448
#
# ...

# %%
df['Folder Number Number'] = pd.to_numeric(df['Folder Number'], errors='coerce')

# %%
df['Folder Number Number'].plot()

# %%
df.plot()
